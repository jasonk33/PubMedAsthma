# %%
using Suppressor
@suppress begin
    include("./Desktop/Code/PubMedAsthma/Functions.jl")
    include("./Desktop/Code/PubMedAsthma/Results.jl")
end;

# %% [markdown]
# ### These were the two queries perfomed:
# ##### Pediatric Asthma: 'asthma[mh] AND (infant[mh] OR child[mh] OR adolescent[mh]) NOT adult[mh] AND (1800[Date - Publication] : 2/13/2014[Date - Publication])'
# ##### Adult Asthma: 'asthma[mh] AND adult[mh] NOT (infant[mh] OR child[mh] OR adolescent[mh]) AND (1800[Date - Publication] : 2/13/2014[Date - Publication])'

# %% [markdown]
# ### The pediatric asthma search returned 24,380 results containing 7,385 unique MeSH descriptors with 117 semantic types; whereas, the adult asthma search returned 23,513 articles containing 8,892 unique MeSH descriptors with 121 semantic types. Absolute counts and relative frequencies for all MeSH descriptors and UMLS semantic types were calculated.

# %%
mesh_descrips_ped
# Out:
# 7374×3 DataFrames.DataFrame
# │ Row  │ count │ mesh_descriptor                │ freq       │
# ├──────┼───────┼────────────────────────────────┼────────────┤
# │ 1    │ 48526 │ "humans"                       │ 0.997862   │
# │ 2    │ 41303 │ "asthma"                       │ 0.977879   │
# │ 3    │ 41150 │ "child"                        │ 0.846265   │
# │ 4    │ 26149 │ "male"                         │ 0.537725   │
# │ 5    │ 26019 │ "female"                       │ 0.535052   │
# │ 6    │ 21129 │ "adolescent"                   │ 0.434563   │
# │ 7    │ 19981 │ "child, preschool"             │ 0.410879   │
# │ 8    │ 11168 │ "infant"                       │ 0.229596   │
# │ 9    │ 4618  │ "risk factors"                 │ 0.0949796  │
# │ 10   │ 4014  │ "prevalence"                   │ 0.0825624  │
# │ 11   │ 3691  │ "surveys and questionnaires"   │ 0.0770528  │
# ⋮
# │ 7363 │ 1     │ "adhesives"                    │ 4.11167e-5 │
# │ 7364 │ 1     │ "acyclovir"                    │ 4.11167e-5 │
# │ 7365 │ 1     │ "actinobacteria"               │ 4.11167e-5 │
# │ 7366 │ 1     │ "acetylglucosaminidase"        │ 4.11167e-5 │
# │ 7367 │ 1     │ "acetylcholinesterase"         │ 4.11167e-5 │
# │ 7368 │ 1     │ "acetyl-coa c-acyltransferase" │ 4.11167e-5 │
# │ 7369 │ 1     │ "acetamides"                   │ 4.11167e-5 │
# │ 7370 │ 1     │ "acanthosis nigricans"         │ 4.11167e-5 │
# │ 7371 │ 1     │ "abruptio placentae"           │ 4.11167e-5 │
# │ 7372 │ 1     │ "abdominal neoplasms"          │ 4.11167e-5 │
# │ 7373 │ 1     │ "6-ketoprostaglandin f1 alpha" │ 4.11167e-5 │
# │ 7374 │ 1     │ "1-propanol"                   │ 4.11167e-5 │

# %%
semantics_ped
# Out:
# 117×3 DataFrames.DataFrame
# │ Row │ count │ semantic_type                      │ freq        │
# ├─────┼───────┼────────────────────────────────────┼─────────────┤
# │ 1   │ 71502 │ "Disease or Syndrome"              │ 1.0         │
# │ 2   │ 96794 │ "Age Group"                        │ 0.999794    │
# │ 3   │ 48526 │ "Human"                            │ 0.997862    │
# │ 4   │ 29734 │ "Organism Attribute"               │ 0.558365    │
# │ 5   │ 29496 │ "Population Group"                 │ 0.550759    │
# │ 6   │ 27136 │ "Pharmacologic Substance"          │ 0.382057    │
# │ 7   │ 24171 │ "Research Activity"                │ 0.353892    │
# │ 8   │ 23320 │ "Quantitative Concept"             │ 0.298836    │
# │ 9   │ 19700 │ "Organic Chemical"                 │ 0.295136    │
# │ 10  │ 17381 │ "Diagnostic Procedure"             │ 0.275893    │
# │ 11  │ 10440 │ "Geographic Area"                  │ 0.257021    │
# ⋮
# │ 106 │ 37    │ "Classification"                   │ 0.00102792  │
# │ 107 │ 47    │ "Professional Society"             │ 0.000986802 │
# │ 108 │ 46    │ "Language"                         │ 0.000945685 │
# │ 109 │ 33    │ "Acquired Abnormality"             │ 0.000904568 │
# │ 110 │ 32    │ "Self-help or Relief Organization" │ 0.000781218 │
# │ 111 │ 29    │ "Bird"                             │ 0.000575634 │
# │ 112 │ 23    │ "Conceptual Entity"                │ 0.000534517 │
# │ 113 │ 14    │ "Organism"                         │ 0.000287817 │
# │ 114 │ 13    │ "Amino Acid Sequence"              │ 0.000287817 │
# │ 115 │ 5     │ "Molecular Sequence"               │ 0.00012335  │
# │ 116 │ 4     │ "Event"                            │ 8.22335e-5  │
# │ 117 │ 3     │ "Anatomical Structure"             │ 8.22335e-5  │

# %%
mesh_descrips_adult
# Out:
# 8892×3 DataFrames.DataFrame
# │ Row  │ count │
# ├──────┼───────┤
# │ 1    │ 23513 │
# │ 2    │ 39114 │
# │ 3    │ 19449 │
# │ 4    │ 18006 │
# │ 5    │ 17769 │
# │ 6    │ 14018 │
# │ 7    │ 6022  │
# │ 8    │ 3549  │
# │ 9    │ 2405  │
# │ 10   │ 2099  │
# │ 11   │ 2007  │
# ⋮
# │ 8881 │ 1     │
# │ 8882 │ 1     │
# │ 8883 │ 1     │
# │ 8884 │ 1     │
# │ 8885 │ 1     │
# │ 8886 │ 1     │
# │ 8887 │ 1     │
# │ 8888 │ 1     │
# │ 8889 │ 1     │
# │ 8890 │ 1     │
# │ 8891 │ 1     │
# │ 8892 │ 1     │
#
# │ Row  │ mesh_descriptor                                                      │
# ├──────┼──────────────────────────────────────────────────────────────────────┤
# │ 1    │ "humans"                                                             │
# │ 2    │ "asthma"                                                             │
# │ 3    │ "adult"                                                              │
# │ 4    │ "male"                                                               │
# │ 5    │ "female"                                                             │
# │ 6    │ "middle aged"                                                        │
# │ 7    │ "aged"                                                               │
# │ 8    │ "forced expiratory volume"                                           │
# │ 9    │ "bronchial provocation tests"                                        │
# │ 10   │ "respiratory function tests"                                         │
# │ 11   │ "administration, inhalation"                                         │
# ⋮
# │ 8881 │ "abdominal wall"                                                     │
# │ 8882 │ "abdominal fat"                                                      │
# │ 8883 │ "6-phytase"                                                          │
# │ 8884 │ "4-quinolones"                                                       │
# │ 8885 │ "4-1bb ligand"                                                       │
# │ 8886 │ "3-iodobenzylguanidine"                                              │
# │ 8887 │ "2-hydroxyphenethylamine"                                            │
# │ 8888 │ "2-chloroadenosine"                                                  │
# │ 8889 │ "15-hydroxy-11 alpha,9 alpha-(epoxymethano)prosta-5,13-dienoic acid" │
# │ 8890 │ "12-hydroxy-5,8,10,14-eicosatetraenoic acid"                         │
# │ 8891 │ "1-propanol"                                                         │
# │ 8892 │ "1-acylglycerophosphocholine o-acyltransferase"                      │
#
# │ Row  │ freq       │
# ├──────┼────────────┤
# │ 1    │ 1.0        │
# │ 2    │ 0.976524   │
# │ 3    │ 0.827159   │
# │ 4    │ 0.765789   │
# │ 5    │ 0.75571    │
# │ 6    │ 0.596181   │
# │ 7    │ 0.256114   │
# │ 8    │ 0.147068   │
# │ 9    │ 0.100625   │
# │ 10   │ 0.088164   │
# │ 11   │ 0.085357   │
# ⋮
# │ 8881 │ 4.25297e-5 │
# │ 8882 │ 4.25297e-5 │
# │ 8883 │ 4.25297e-5 │
# │ 8884 │ 4.25297e-5 │
# │ 8885 │ 4.25297e-5 │
# │ 8886 │ 4.25297e-5 │
# │ 8887 │ 4.25297e-5 │
# │ 8888 │ 4.25297e-5 │
# │ 8889 │ 4.25297e-5 │
# │ 8890 │ 4.25297e-5 │
# │ 8891 │ 4.25297e-5 │
# │ 8892 │ 4.25297e-5 │

# %%
semantics_adult
# Out:
# 121×3 DataFrames.DataFrame
# │ Row │ count │ semantic_type                         │ freq        │
# ├─────┼───────┼───────────────────────────────────────┼─────────────┤
# │ 1   │ 73397 │ "Disease or Syndrome"                 │ 1.0         │
# │ 2   │ 23513 │ "Human"                               │ 1.0         │
# │ 3   │ 35082 │ "Age Group"                           │ 0.969081    │
# │ 4   │ 25095 │ "Organism Attribute"                  │ 0.811041    │
# │ 5   │ 18405 │ "Population Group"                    │ 0.758517    │
# │ 6   │ 34267 │ "Pharmacologic Substance"             │ 0.518266    │
# │ 7   │ 28676 │ "Organic Chemical"                    │ 0.468124    │
# │ 8   │ 14397 │ "Diagnostic Procedure"                │ 0.420959    │
# │ 9   │ 11277 │ "Research Activity"                   │ 0.339897    │
# │ 10  │ 9123  │ "Quantitative Concept"                │ 0.251435    │
# │ 11  │ 7358  │ "Therapeutic or Preventive Procedure" │ 0.235997    │
# ⋮
# │ 110 │ 19    │ "Language"                            │ 0.000808064 │
# │ 111 │ 15    │ "Professional Society"                │ 0.000595415 │
# │ 112 │ 12    │ "Self-help or Relief Organization"    │ 0.000510356 │
# │ 113 │ 12    │ "Organism"                            │ 0.000510356 │
# │ 114 │ 6     │ "Reptile"                             │ 0.000255178 │
# │ 115 │ 5     │ "Molecular Sequence"                  │ 0.000212648 │
# │ 116 │ 4     │ "Conceptual Entity"                   │ 0.000170119 │
# │ 117 │ 3     │ "Anatomical Structure"                │ 0.000127589 │
# │ 118 │ 2     │ "Physical Object"                     │ 8.50593e-5  │
# │ 119 │ 2     │ "Amphibian"                           │ 8.50593e-5  │
# │ 120 │ 1     │ "Event"                               │ 4.25297e-5  │
# │ 121 │ 1     │ "Carbohydrate Sequence"               │ 4.25297e-5  │

# %% [markdown]
# ### The top 25 MeSH descriptors and top ten semantic types ordered by frequency were chosen to be displayed as histograms

# %%
load("./Desktop/Code/PubMedAsthma/Plots/Top25MeshPed.pdf")
# Out:
# 450×700 Array{RGBA{N0f8},2}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)

# %%
load("./Desktop/Code/PubMedAsthma/Plots/Top10SemanticsPed.pdf")
# Out:
# 450×700 Array{RGBA{N0f8},2}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.8,0.82,0.855,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.361,0.318,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.557,0.722,0.855,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.529,0.361,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.906,0.922,0.922,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.267,0.267,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)

# %%
load("./Desktop/Code/PubMedAsthma/Plots/Top25MeshAdult.pdf")
# Out:
# 450×700 Array{RGBA{N0f8},2}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)

# %%
load("./Desktop/Code/PubMedAsthma/Plots/Top10SemanticsAdult.pdf")
# Out:
# 450×700 Array{RGBA{N0f8},2}:
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.957,0.937,0.906,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.557,0.267,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.702,0.471,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.267,0.267,0.267,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.318,0.584,0.8,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.839,0.969,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.922,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)  …  RGBA{N0f8}(0.267,0.267,0.439,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(0.8,0.741,0.761,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)
#  RGBA{N0f8}(1.0,1.0,1.0,1.0)     RGBA{N0f8}(1.0,1.0,1.0,1.0)

# %% [markdown]
# ### MeSH descriptors were subsequently filtered by the following three UMLS semantic types in the UMLS Semantic Network: (1) “Disease or Syndrome,” (2) “Mental or Behavioral Dysfunction,” and (3) “Neoplastic Process,” where the latter two are children of the first. After the filtering step, 1,016 MeSH descriptors were left for pediatric asthma and 1,213 MeSH descriptors remained for adult asthma.

# %%
mesh_descrips_filtered_ped
# Out:
# 1016×3 DataFrames.DataFrame
# │ Row  │ count │ mesh_descriptor                 │ freq       │
# ├──────┼───────┼─────────────────────────────────┼────────────┤
# │ 1    │ 41303 │ "asthma"                        │ 0.977879   │
# │ 2    │ 1938  │ "acute disease"                 │ 0.0399243  │
# │ 3    │ 1880  │ "chronic disease"               │ 0.0399243  │
# │ 4    │ 1225  │ "rhinitis, allergic, seasonal"  │ 0.0319066  │
# │ 5    │ 1126  │ "bronchitis"                    │ 0.0314132  │
# │ 6    │ 1269  │ "dermatitis, atopic"            │ 0.0310842  │
# │ 7    │ 1218  │ "respiratory tract infections"  │ 0.0307142  │
# │ 8    │ 1162  │ "asthma, exercise-induced"      │ 0.0285761  │
# │ 9    │ 1199  │ "bronchial hyperreactivity"     │ 0.0282061  │
# │ 10   │ 1042  │ "rhinitis, allergic, perennial" │ 0.0244645  │
# │ 11   │ 864   │ "eczema"                        │ 0.0231076  │
# ⋮
# │ 1005 │ 1     │ "anthrax"                       │ 4.11167e-5 │
# │ 1006 │ 1     │ "aneurysm, infected"            │ 4.11167e-5 │
# │ 1007 │ 1     │ "aneurysm"                      │ 4.11167e-5 │
# │ 1008 │ 1     │ "anemia, hemolytic"             │ 4.11167e-5 │
# │ 1009 │ 1     │ "amblyopia"                     │ 4.11167e-5 │
# │ 1010 │ 1     │ "altitude sickness"             │ 4.11167e-5 │
# │ 1011 │ 1     │ "alpha-thalassemia"             │ 4.11167e-5 │
# │ 1012 │ 1     │ "alopecia areata"               │ 4.11167e-5 │
# │ 1013 │ 1     │ "alopecia"                      │ 4.11167e-5 │
# │ 1014 │ 1     │ "alcoholic intoxication"        │ 4.11167e-5 │
# │ 1015 │ 1     │ "acanthosis nigricans"          │ 4.11167e-5 │
# │ 1016 │ 1     │ "abdominal neoplasms"           │ 4.11167e-5 │

# %%
mesh_descrips_filtered_adult
# Out:
# 1213×3 DataFrames.DataFrame
# │ Row  │ count │ mesh_descriptor                          │ freq       │
# ├──────┼───────┼──────────────────────────────────────────┼────────────┤
# │ 1    │ 39114 │ "asthma"                                 │ 0.976524   │
# │ 2    │ 2938  │ "occupational diseases"                  │ 0.0729809  │
# │ 3    │ 1309  │ "chronic disease"                        │ 0.0548207  │
# │ 4    │ 1700  │ "bronchitis"                             │ 0.0523115  │
# │ 5    │ 1520  │ "bronchial hyperreactivity"              │ 0.0405308  │
# │ 6    │ 1542  │ "pulmonary disease, chronic obstructive" │ 0.0362778  │
# │ 7    │ 786   │ "acute disease"                          │ 0.0334283  │
# │ 8    │ 1079  │ "lung diseases, obstructive"             │ 0.0298984  │
# │ 9    │ 888   │ "rhinitis, allergic, seasonal"           │ 0.0228384  │
# │ 10   │ 828   │ "rhinitis"                               │ 0.0217752  │
# │ 11   │ 703   │ "airway obstruction"                     │ 0.0193085  │
# ⋮
# │ 1202 │ 1     │ "anemia, macrocytic"                     │ 4.25297e-5 │
# │ 1203 │ 1     │ "anemia, hypochromic"                    │ 4.25297e-5 │
# │ 1204 │ 1     │ "amyotrophic lateral sclerosis"          │ 4.25297e-5 │
# │ 1205 │ 1     │ "alphavirus infections"                  │ 4.25297e-5 │
# │ 1206 │ 1     │ "alopecia areata"                        │ 4.25297e-5 │
# │ 1207 │ 1     │ "alcohol amnestic disorder"              │ 4.25297e-5 │
# │ 1208 │ 1     │ "aids-related complex"                   │ 4.25297e-5 │
# │ 1209 │ 1     │ "adrenal hyperplasia, congenital"        │ 4.25297e-5 │
# │ 1210 │ 1     │ "adenovirus infections, human"           │ 4.25297e-5 │
# │ 1211 │ 1     │ "adenocarcinoma, follicular"             │ 4.25297e-5 │
# │ 1212 │ 1     │ "acalculous cholecystitis"               │ 4.25297e-5 │
# │ 1213 │ 1     │ "abortion, habitual"                     │ 4.25297e-5 │

# %% [markdown]
# ### The tool carried out basic statistical analysis again on these filtered MeSH descriptors and further generated association rules using user-specified parameters. To maximize the rules generated by PubMedMiner, a minimum support of 0.01, minimum confidence of 0.01, and maximum rule length of 3 were specified as the settings

# %%
association_rules_ped
# Out:
# 32×6 DataFrames.DataFrame
# │ Row │ lhs                          │ rhs                            │
# ├─────┼──────────────────────────────┼────────────────────────────────┤
# │ 1   │ "asthma"                     │ "asthma, exercise-induced"     │
# │ 2   │ "asthma, exercise-induced"   │ "asthma"                       │
# │ 3   │ "asthma"                     │ "chronic disease"              │
# │ 4   │ "chronic disease"            │ "asthma"                       │
# │ 5   │ "asthma"                     │ "dermatitis, atopic"           │
# │ 6   │ "dermatitis, atopic"         │ "asthma"                       │
# │ 7   │ "asthma"                     │ "bronchitis"                   │
# │ 8   │ "bronchitis"                 │ "asthma"                       │
# │ 9   │ "asthma"                     │ "bronchial hyperreactivity"    │
# │ 10  │ "bronchial hyperreactivity"  │ "asthma"                       │
# │ 11  │ "asthma"                     │ "rhinitis, allergic, seasonal" │
# ⋮
# │ 21  │ "asthma"                     │ "cystic fibrosis"              │
# │ 22  │ "cystic fibrosis"            │ "asthma"                       │
# │ 23  │ "airway obstruction"         │ "asthma"                       │
# │ 24  │ "asthma"                     │ "airway obstruction"           │
# │ 25  │ "asthma"                     │ "respiratory tract diseases"   │
# │ 26  │ "respiratory tract diseases" │ "asthma"                       │
# │ 27  │ "obesity"                    │ "asthma"                       │
# │ 28  │ "asthma"                     │ "obesity"                      │
# │ 29  │ "pneumonia"                  │ "asthma"                       │
# │ 30  │ "asthma"                     │ "pneumonia"                    │
# │ 31  │ "acute disease"              │ "asthma"                       │
# │ 32  │ "asthma"                     │ "acute disease"                │
#
# │ Row │ support   │ confidence │ lift     │ chi_squared │
# ├─────┼───────────┼────────────┼──────────┼─────────────┤
# │ 1   │ 0.0153777 │ 0.0157255  │ 0.550303 │ 98.3538     │
# │ 2   │ 0.0153777 │ 0.538129   │ 0.550303 │ 98.3538     │
# │ 3   │ 0.0397188 │ 0.0406172  │ 1.01736  │ 0.534887    │
# │ 4   │ 0.0397188 │ 0.994851   │ 1.01736  │ 0.534887    │
# │ 5   │ 0.031002  │ 0.0317033  │ 1.01992  │ 0.424139    │
# │ 6   │ 0.031002  │ 0.997354   │ 1.01992  │ 0.424139    │
# │ 7   │ 0.0312898 │ 0.0319976  │ 1.01861  │ 0.377688    │
# │ 8   │ 0.0312898 │ 0.996073   │ 1.01861  │ 0.377688    │
# │ 9   │ 0.0270959 │ 0.0277089  │ 0.982372 │ 0.262743    │
# │ 10  │ 0.0270959 │ 0.960641   │ 0.982372 │ 0.262743    │
# │ 11  │ 0.0316599 │ 0.0323761  │ 1.01471  │ 0.242895    │
# ⋮
# │ 21  │ 0.013733  │ 0.0140436  │ 1.01957  │ 0.0789655   │
# │ 22  │ 0.013733  │ 0.997015   │ 1.01957  │ 0.0789655   │
# │ 23  │ 0.0128695 │ 0.960123   │ 0.981842 │ 0.0619826   │
# │ 24  │ 0.0128695 │ 0.0131607  │ 0.981842 │ 0.0619826   │
# │ 25  │ 0.0141853 │ 0.0145062  │ 1.01673  │ 0.061764    │
# │ 26  │ 0.0141853 │ 0.994236   │ 1.01673  │ 0.061764    │
# │ 27  │ 0.0111015 │ 0.957447   │ 0.979105 │ 0.0611292   │
# │ 28  │ 0.0111015 │ 0.0113526  │ 0.979105 │ 0.0611292   │
# │ 29  │ 0.0151721 │ 0.991935   │ 1.01437  │ 0.0523524   │
# │ 30  │ 0.0151721 │ 0.0155153  │ 1.01437  │ 0.0523524   │
# │ 31  │ 0.0389375 │ 0.975283   │ 0.997345 │ 0.0122688   │
# │ 32  │ 0.0389375 │ 0.0398184  │ 0.997345 │ 0.0122688   │

# %%
association_rules_adult
# Out:
# 43×6 DataFrames.DataFrame
# │ Row │ lhs                                      │
# ├─────┼──────────────────────────────────────────┤
# │ 1   │ "chronic disease,asthma"                 │
# │ 2   │ "bronchitis,asthma"                      │
# │ 3   │ "bronchitis"                             │
# │ 4   │ "chronic disease"                        │
# │ 5   │ "bronchitis"                             │
# │ 6   │ "asthma"                                 │
# │ 7   │ "chronic disease"                        │
# │ 8   │ "asthma"                                 │
# │ 9   │ "occupational diseases"                  │
# │ 10  │ "asthma"                                 │
# │ 11  │ "pulmonary disease, chronic obstructive" │
# ⋮
# │ 32  │ "hypertension"                           │
# │ 33  │ "asthma"                                 │
# │ 34  │ "asthma"                                 │
# │ 35  │ "acute disease"                          │
# │ 36  │ "rhinitis, allergic, perennial"          │
# │ 37  │ "asthma"                                 │
# │ 38  │ "pneumonia"                              │
# │ 39  │ "asthma"                                 │
# │ 40  │ "bronchial spasm"                        │
# │ 41  │ "asthma"                                 │
# │ 42  │ "asthma"                                 │
# │ 43  │ "bronchial hyperreactivity"              │
#
# │ Row │ rhs                             │ support   │ confidence │ lift     │
# ├─────┼─────────────────────────────────┼───────────┼────────────┼──────────┤
# │ 1   │ "bronchitis"                    │ 0.0194786 │ 0.35642    │ 6.81342  │
# │ 2   │ "chronic disease"               │ 0.0194786 │ 0.372964   │ 6.80334  │
# │ 3   │ "chronic disease"               │ 0.0194786 │ 0.372358   │ 6.79228  │
# │ 4   │ "bronchitis"                    │ 0.0194786 │ 0.355314   │ 6.79228  │
# │ 5   │ "asthma"                        │ 0.0522264 │ 0.998374   │ 1.02238  │
# │ 6   │ "bronchitis"                    │ 0.0522264 │ 0.053482   │ 1.02238  │
# │ 7   │ "asthma"                        │ 0.0546506 │ 0.996897   │ 1.02086  │
# │ 8   │ "chronic disease"               │ 0.0546506 │ 0.0559645  │ 1.02086  │
# │ 9   │ "asthma"                        │ 0.0720027 │ 0.986597   │ 1.01032  │
# │ 10  │ "occupational diseases"         │ 0.0720027 │ 0.0737337  │ 1.01032  │
# │ 11  │ "asthma"                        │ 0.0360652 │ 0.994138   │ 1.01804  │
# ⋮
# │ 32  │ "asthma"                        │ 0.0102496 │ 0.99177    │ 1.01561  │
# │ 33  │ "hypertension"                  │ 0.0102496 │ 0.0104961  │ 1.01561  │
# │ 34  │ "acute disease"                 │ 0.0324927 │ 0.0332738  │ 0.995378 │
# │ 35  │ "asthma"                        │ 0.0324927 │ 0.97201    │ 0.995378 │
# │ 36  │ "asthma"                        │ 0.0186705 │ 0.984305   │ 1.00797  │
# │ 37  │ "rhinitis, allergic, perennial" │ 0.0186705 │ 0.0191194  │ 1.00797  │
# │ 38  │ "asthma"                        │ 0.01076   │ 0.988281   │ 1.01204  │
# │ 39  │ "pneumonia"                     │ 0.01076   │ 0.0110187  │ 1.01204  │
# │ 40  │ "asthma"                        │ 0.0182452 │ 0.972789   │ 0.996176 │
# │ 41  │ "bronchial spasm"               │ 0.0182452 │ 0.0186839  │ 0.996176 │
# │ 42  │ "bronchial hyperreactivity"     │ 0.0395951 │ 0.040547   │ 1.0004   │
# │ 43  │ "asthma"                        │ 0.0395951 │ 0.976915   │ 1.0004   │
#
# │ Row │ chi_squared │
# ├─────┼─────────────┤
# │ 1   │ 49.3928     │
# │ 2   │ 49.299      │
# │ 3   │ 49.1956     │
# │ 4   │ 49.1956     │
# │ 5   │ 1.41167     │
# │ 6   │ 1.41167     │
# │ 7   │ 1.34939     │
# │ 8   │ 1.34939     │
# │ 9   │ 0.589917    │
# │ 10  │ 0.589917    │
# │ 11  │ 0.432038    │
# ⋮
# │ 32  │ 0.0255165   │
# │ 33  │ 0.0255165   │
# │ 34  │ 0.0234788   │
# │ 35  │ 0.0234788   │
# │ 36  │ 0.0224181   │
# │ 37  │ 0.0224181   │
# │ 38  │ 0.0167932   │
# │ 39  │ 0.0167932   │
# │ 40  │ 0.00498843  │
# │ 41  │ 0.00498843  │
# │ 42  │ 0.000262777 │
# │ 43  │ 0.000262777 │

# %% [markdown]
# ### According to the statistical analysis of the extracted UMLS semantic types, most semantic types (80.0%) in both sets of articles had similar frequencies (< 2 fold difference). For example, both sets of articles included the same top five UMLS semantic types ordered by frequency without duplicates: “Age Group,” “Population Group,” “Human,” “Disease or Syndrome,” and “Organism Attribute.” Several semantic types had frequencies with greater than a two-fold difference. For example, the frequency of the semantic types “Family Group,” “Environmental Effect of Humans,” “Conceptual Entity,” “Organization,” and “Regulation or Law” were higher in publications related to pediatric asthma. “Anatomical Abnormality,” “Body Substance,” “Cell Function,” and “Neoplastic Process” appeared more often in articles for adult asthma. Similarly, the frequency patterns of MeSH descriptors after filtering differed between the two sets of articles. The following tables present a selection of MeSH descriptors that had relative frequencies greater than 2%.

# %%
mesh_descrips_filtered_ped[mesh_descrips_filtered_ped[:freq] .> .02,:]
# Out:
# 11×3 DataFrames.DataFrame
# │ Row │ count │ mesh_descriptor                 │ freq      │
# ├─────┼───────┼─────────────────────────────────┼───────────┤
# │ 1   │ 41303 │ "asthma"                        │ 0.977879  │
# │ 2   │ 1938  │ "acute disease"                 │ 0.0399243 │
# │ 3   │ 1880  │ "chronic disease"               │ 0.0399243 │
# │ 4   │ 1225  │ "rhinitis, allergic, seasonal"  │ 0.0319066 │
# │ 5   │ 1126  │ "bronchitis"                    │ 0.0314132 │
# │ 6   │ 1269  │ "dermatitis, atopic"            │ 0.0310842 │
# │ 7   │ 1218  │ "respiratory tract infections"  │ 0.0307142 │
# │ 8   │ 1162  │ "asthma, exercise-induced"      │ 0.0285761 │
# │ 9   │ 1199  │ "bronchial hyperreactivity"     │ 0.0282061 │
# │ 10  │ 1042  │ "rhinitis, allergic, perennial" │ 0.0244645 │
# │ 11  │ 864   │ "eczema"                        │ 0.0231076 │

# %%
mesh_descrips_filtered_adult[mesh_descrips_filtered_adult[:freq] .> .02,:]
# Out:
# 10×3 DataFrames.DataFrame
# │ Row │ count │ mesh_descriptor                          │ freq      │
# ├─────┼───────┼──────────────────────────────────────────┼───────────┤
# │ 1   │ 39114 │ "asthma"                                 │ 0.976524  │
# │ 2   │ 2938  │ "occupational diseases"                  │ 0.0729809 │
# │ 3   │ 1309  │ "chronic disease"                        │ 0.0548207 │
# │ 4   │ 1700  │ "bronchitis"                             │ 0.0523115 │
# │ 5   │ 1520  │ "bronchial hyperreactivity"              │ 0.0405308 │
# │ 6   │ 1542  │ "pulmonary disease, chronic obstructive" │ 0.0362778 │
# │ 7   │ 786   │ "acute disease"                          │ 0.0334283 │
# │ 8   │ 1079  │ "lung diseases, obstructive"             │ 0.0298984 │
# │ 9   │ 888   │ "rhinitis, allergic, seasonal"           │ 0.0228384 │
# │ 10  │ 828   │ "rhinitis"                               │ 0.0217752 │

# %% [markdown]
# ### The fold differences of relative frequencies were calculated for MeSH descriptors that were higher than 0.5% between the two sets, and fold differences greater than two are highlighted in the following tables, which show MeSH descriptors with fold difference greater than five.

# %%
mesh_fold(mesh_descrips_filtered_ped,mesh_descrips_filtered_adult)[1]
# Out:
# 8×2 DataFrames.DataFrame
# │ Row │ mesh_descriptor                          │ fold_ped │
# ├─────┼──────────────────────────────────────────┼──────────┤
# │ 1   │ "bronchiolitis, viral"                   │ 77.3422  │
# │ 2   │ "respiratory syncytial virus infections" │ 16.611   │
# │ 3   │ "virus diseases"                         │ 10.6346  │
# │ 4   │ "bronchiolitis"                          │ 10.0748  │
# │ 5   │ "diabetes mellitus, type 1"              │ 9.26495  │
# │ 6   │ "cystic fibrosis"                        │ 7.19712  │
# │ 7   │ "dermatitis, atopic"                     │ 6.35551  │
# │ 8   │ "eczema"                                 │ 6.17419  │

# %%
mesh_fold(mesh_descrips_filtered_ped,mesh_descrips_filtered_adult)[2]
# Out:
# 9×2 DataFrames.DataFrame
# │ Row │ mesh_descriptor                            │ fold_adult │
# ├─────┼────────────────────────────────────────────┼────────────┤
# │ 1   │ "occupational diseases"                    │ 45.512     │
# │ 2   │ "pulmonary disease, chronic obstructive"   │ 28.4617    │
# │ 3   │ "nasal polyps"                             │ 16.1239    │
# │ 4   │ "churg-strauss syndrome"                   │ 9.90034    │
# │ 5   │ "lung neoplasms"                           │ 9.0659     │
# │ 6   │ "lung diseases, obstructive"               │ 7.57456    │
# │ 7   │ "hypertension"                             │ 7.18144    │
# │ 8   │ "pulmonary emphysema"                      │ 6.31589    │
# │ 9   │ "aspergillosis, allergic bronchopulmonary" │ 5.689      │

# %% [markdown]
# ### Several MeSH descriptors were more frequently mentioned for pediatric asthma such as “Virus Diseases,” “Respiratory Syncytial Virus Infections,” “Bronchiolitis, Viral” and “Diabetes Mellitus, Type 1”. Some descriptors were more frequent for adult asthma such as “Occupational Diseases,” “Pulmonary Disease, Chronic Obstructive,” “Hypertension,” “Lung Diseases, Obstructive,” and “Churg-Strauss Syndrome”. This type of analysis enables one to explore potential asthma-related diseases and reveals those that are more studied relative to the two patient populations (children and adults).

# %%
@suppress_err begin
    arules_viz(itemsets_ped, "grouped", 18)
end;

# %%
@suppress_err begin
    arules_viz(itemsets_adult, "grouped", 18)
end;

# %%
@suppress_err begin
    arules_viz(itemsets_ped, "graph")
end;

# %%
@suppress_err begin
    arules_viz(itemsets_adult, "graph")
end;
